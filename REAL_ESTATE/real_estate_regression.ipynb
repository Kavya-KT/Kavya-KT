# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Datasets/Real estate.csv')
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.drop(['No','X1 transaction date'],axis=1,inplace=True)
df
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# ...

# %%
df.dtypes
# Out:
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
df.isna().sum()
# Out:
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
X=df.iloc[:,:-1]
X
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
m=MinMaxScaler()
X_s=m.fit_transform(X)
X_s
# Out:
# array([[0.73059361, 0.00951267, 1.        , 0.61694135, 0.71932284],
#        [0.44520548, 0.04380939, 0.9       , 0.5849491 , 0.71145137],
#        [0.30365297, 0.08331505, 0.5       , 0.67123122, 0.75889584],
#        ...,
#        [0.42922374, 0.05686115, 0.7       , 0.57149782, 0.71522536],
#        [0.18493151, 0.0125958 , 0.5       , 0.42014057, 0.72395946],
#        [0.14840183, 0.0103754 , 0.9       , 0.51211827, 0.75016174]])

# %%
X_train,X_test,y_train,y_test=train_test_split(X_s,y,test_size=0.3,random_state=5)

# %%
X_train.shape,X_test.shape
# Out:
# ((289, 5), (125, 5))

# %%
y_train.shape,y_test.shape
# Out:
# ((289,), (125,))

# %%
k=KNeighborsRegressor(n_neighbors=3)
d=DecisionTreeRegressor(random_state=5)
a=AdaBoostRegressor(random_state=1)
r=RandomForestRegressor(random_state=5)
x=XGBRegressor()
l=[k,d,a,r,x]
for i in l:
  print(i)
  i.fit(X_train,y_train)
  y_pred=i.predict(X_test)
  print()
  print('r2scor=',r2_score(y_test,y_pred))
  print('MAE=',mean_absolute_error(y_test,y_pred))
  print('MSE=',mean_squared_error(y_test,y_pred))
  print('RMSE=',np.sqrt(mean_squared_error(y_test,y_pred)))
  print()
# Out:
# KNeighborsRegressor(n_neighbors=3)
#
# r2scor= 0.7653676875353292
# MAE= 4.1778666666666675
# MSE= 36.21568888888889
# RMSE= 6.0179472321456
#
# DecisionTreeRegressor(random_state=5)
#
# r2scor= 0.6612606145499382
# MAE= 5.059533333333333
# MSE= 52.28470055555556
# RMSE= 7.230816036627924
#
# AdaBoostRegressor(random_state=1)
#
# r2scor= 0.6966528030589547
# MAE= 5.139908674669278
# MSE= 46.821887379163044
# RMSE= 6.842652072052403
#
# RandomForestRegressor(random_state=5)
#
# r2scor= 0.7362436646656014
# MAE= 4.3036558107448135
# MSE= 40.71100558403404
# RMSE= 6.380517657998765
#
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
# ...

# %%
l=[{'knn':r2_score(y_test,k.predict(X_test)),'RFR':r2_score(y_test,r.predict(X_test)),'Decisiontree':r2_score(y_test,d.predict(X_test)),'adaboost':r2_score(y_test,a.predict(X_test)),'XGB':r2_score(y_test,x.predict(X_test))}]

# %%
d=pd.DataFrame(l,index=['r2score'])
d
# Out:
#               knn       RFR  Decisiontree  adaboost       XGB
# r2score  0.765368  0.736244      0.661261  0.696653  0.749991

# %% [markdown]
# here knn is best method

# %%
knn=KNeighborsRegressor(n_neighbors=3)
knn.fit(X_train,y_train)
y_pred_knn=knn.predict(X_test)

print('r2scor=',r2_score(y_test,y_pred_knn))
print('MAE=',mean_absolute_error(y_test,y_pred_knn))
print('MSE=',mean_squared_error(y_test,y_pred_knn))
print('RMSE=',np.sqrt(mean_squared_error(y_test,y_pred_knn)))
# Out:
# r2scor= 0.7653676875353292
# MAE= 4.1778666666666675
# MSE= 36.21568888888889
# RMSE= 6.0179472321456

# %%
y_pred_n=k.predict(m.transform([[32.0,84.87882,10,24.98298,121.54024]]))
y_pred_n
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([47.06666667])

# %%
pickle.dump(knn,open('realestate','wb'))
pickle.dump(m,open('scaler','wb'))
